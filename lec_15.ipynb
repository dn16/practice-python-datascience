# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
nlf_frame = pd.read_clipboard()

# %%
nlf_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East
# 5       1,289   NFC East

# %%
nlf_frame.columns
# Out:
# Index(['Rank', 'Team', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Total Games', 'Division'],
#       dtype='object')

# %%
nlf_frame['First NFL Season']
# Out:
# 0    1960
# 1    1921
# 2    1920
# 3    1966
# 4    1960
# 5    1925
# Name: First NFL Season, dtype: int64

# %%
nlf_frame.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# 5            New York Giants
# Name: Team, dtype: object

# %%
nlf_frame[['Team','First NFL Season']]
# Out:
#                       Team  First NFL Season
# 0           Dallas Cowboys              1960
# 1        Green Bay Packers              1921
# 2            Chicago Bears              1920
# 3           Miami Dolphins              1966
# 4  New England Patriots[b]              1960
# 5          New York Giants              1925

# %%
DataFrame(nlf_frame, columns=['Team', 'First NFL Season'])
# Out:
#                       Team  First NFL Season
# 0           Dallas Cowboys              1960
# 1        Green Bay Packers              1921
# 2            Chicago Bears              1920
# 3           Miami Dolphins              1966
# 4  New England Patriots[b]              1960
# 5          New York Giants              1925

# %%
DataFrame(nlf_frame, columns=['Team', 'First NFL Season','Stadium'])
# Out:
#                       Team  First NFL Season  Stadium
# 0           Dallas Cowboys              1960      NaN
# 1        Green Bay Packers              1921      NaN
# 2            Chicago Bears              1920      NaN
# 3           Miami Dolphins              1966      NaN
# 4  New England Patriots[b]              1960      NaN
# 5          New York Giants              1925      NaN

# %%
nlf_frame.head()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East

# %%
nlf_frame.head(3)
# Out:
#    Rank               Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0     Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0  Green Bay Packers  730   553    37  0.567              1921
# 2   3.0      Chicago Bears  744   568    42  0.565              1920
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North

# %%
nlf_frame.tail()
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East
# 5       1,289   NFC East

# %%
nlf_frame.tail(3)
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games  Division
# 3         784  AFC East
# 4         868  AFC East
# 5       1,289  NFC East

# %%
nlf_frame.loc[[3],:]
# Out:
#    Rank            Team  Won  Lost  Tied   Pct.  First NFL Season Total Games  \
# 3   4.0  Miami Dolphins  439   341     4  0.563              1966         784
#
#    Division
# 3  AFC East

# %%
nlf_frame.loc[3,:]
# Out:
# Rank                             4
# Team                Miami Dolphins
# Won                            439
# Lost                           341
# Tied                             4
# Pct.                         0.563
# First NFL Season              1966
# Total Games                    784
# Division                  AFC East
# Name: 3, dtype: object

# %%
nlf_frame["Stadium"] = "Levi's Stadium"

# %%
nlf_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division         Stadium
# 0         860   NFC East  Levi's Stadium
# 1       1,320  NFC North  Levi's Stadium
# 2       1,354  NFC North  Levi's Stadium
# 3         784   AFC East  Levi's Stadium
# 4         868   AFC East  Levi's Stadium
# 5       1,289   NFC East  Levi's Stadium

# %%
nlf_frame["Stadium"] = np.arange(6)

# %%
nlf_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division  Stadium
# 0         860   NFC East        0
# 1       1,320  NFC North        1
# 2       1,354  NFC North        2
# 3         784   AFC East        3
# 4         868   AFC East        4
# 5       1,289   NFC East        5

# %%
stadiums = Series(["Levi's Stadium", "AT&T Stadium"], index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nlf_frame["Stadium"] = stadiums

# %%
nlf_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division         Stadium
# 0         860   NFC East    AT&T Stadium
# 1       1,320  NFC North             NaN
# 2       1,354  NFC North             NaN
# 3         784   AFC East             NaN
# 4         868   AFC East  Levi's Stadium
# 5       1,289   NFC East             NaN

# %%
del nlf_frame['Stadium']

# %%
nlf_frame
# Out:
#    Rank                     Team  Won  Lost  Tied   Pct.  First NFL Season  \
# 0   1.0           Dallas Cowboys  511   367     1  0.573              1960
# 1   2.0        Green Bay Packers  730   553    37  0.567              1921
# 2   3.0            Chicago Bears  744   568    42  0.565              1920
# 3   4.0           Miami Dolphins  439   341     4  0.563              1966
# 4   5.0  New England Patriots[b]  476   383     9  0.554              1960
# 5   6.0          New York Giants  684   572    33  0.543              1925
#
#   Total Games   Division
# 0         860   NFC East
# 1       1,320  NFC North
# 2       1,354  NFC North
# 3         784   AFC East
# 4         868   AFC East
# 5       1,289   NFC East

# %%
data = {'City':['SF', 'LA', 'NYC'], 'Population':[837000,3880000,8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
